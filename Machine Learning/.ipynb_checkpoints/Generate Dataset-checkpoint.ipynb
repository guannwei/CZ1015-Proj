# %% [markdown]
# ## Split dataset into train and test

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
from numpy import savetxt

from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Import dataset

# %%
aviation = pd.read_csv('../Data/AviationFinal.csv')
aviation
# Out:
#               EventID WeatherCondition BroadPhaseOfFlight AircraftDamage  \
# 0      20161117X64217              UNK        MANEUVERING    Substantial
# 1      20161116X13203              VMC            LANDING    Substantial
# 2      20161116X62135              VMC            TAKEOFF    Substantial
# 3      20161114X41943              VMC        MANEUVERING    Substantial
# 4      20161116X04207              VMC            UNKNOWN    Substantial
# ...               ...              ...                ...            ...
# 79136  20041105X01764              VMC           APPROACH      Destroyed
# 79137  20001218X45448              IMC             CRUISE      Destroyed
# 79138  20061025X01555              IMC             CRUISE      Destroyed
# 79139  20001218X45447              UNK            UNKNOWN      Destroyed
# 79140  20001218X45444              UNK             CRUISE      Destroyed
#
#       InvestigationType PurposeOfFlight AircraftCategory     EngineType  \
# 0              Accident         Unknown       Helicopter    Turbo Shaft
# 1              Accident         Unknown         Airplane        Unknown
# 2              Accident        Personal         Airplane  Reciprocating
# 3              Accident   Instructional         Airplane  Reciprocating
# 4              Accident        Personal         Airplane  Reciprocating
# ...                 ...             ...              ...            ...
# 79136          Accident        Personal          Unknown        Unknown
# 79137          Accident        Personal          Unknown  Reciprocating
# 79138          Accident        Personal          Unknown  Reciprocating
# 79139          Accident        Personal          Unknown  Reciprocating
# 79140          Accident        Personal          Unknown  Reciprocating
#
#              Country   Latitude  ...  TotalFatalInjuries TotalSeriousInjuries  \
# 0        New Zealand  37.703398  ...                 0.0                  0.0
# 1             Panama  37.703398  ...                 0.0                  0.0
# 2      United States  30.532500  ...                 0.0                  0.0
# 3      United States  34.454722  ...                 0.0                  0.0
# 4      United States  37.703398  ...                 0.0                  1.0
# ...              ...        ...  ...                 ...                  ...
# 79136  United States  37.703398  ...                 1.0                  2.0
# 79137  United States  37.703398  ...                 2.0                  0.0
# 79138  United States  36.922223  ...                 3.0                  0.0
# 79139  United States  37.703398  ...                 4.0                  0.0
# 79140  United States  37.703398  ...                 2.0                  0.0
#
#        TotalMinorInjuries  TotalUninjured  TotalInjuries  InjurySeverity  \
# 0                     0.0             1.0            0.0       Non-Fatal
# 1                     0.0             2.0            0.0       Non-Fatal
# 2                     0.0             1.0            0.0       Non-Fatal
# 3                     0.0             2.0            0.0       Non-Fatal
# 4                     0.0             1.0            1.0       Non-Fatal
# ...                   ...             ...            ...             ...
# 79136                 0.0             0.0            3.0        Fatal(1)
# 79137                 0.0             0.0            2.0        Fatal(2)
# 79138                 0.0             0.0            3.0        Fatal(3)
# 79139                 0.0             0.0            4.0        Fatal(4)
# 79140                 0.0             0.0            2.0        Fatal(2)
#
#        NumberOfEngines   EventDate  Month  Year
# 0              1.00000  2016-11-14     11  2016
# 1              1.14797  2016-11-14     11  2016
# 2              1.00000  2016-11-13     11  2016
# 3              1.00000  2016-12-11     12  2016
# 4              1.00000  2016-12-11     12  2016
# ...                ...         ...    ...   ...
# 79136          1.14797  1979-02-08      2  1979
# 79137          1.00000  1977-06-19      6  1977
# 79138          1.00000  1974-08-30      8  1974
# 79139          1.00000  1962-07-19      7  1962
# 79140          1.00000  1948-10-24     10  1948
#
# [79141 rows x 22 columns]

# %% [markdown]
# ### Split data into train and test

# %%
x=aviation.drop(['AircraftDamage'],axis=1)
y=aviation.AircraftDamage.values

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

# %% [markdown]
# ### Convert numpy array to data frame

# %%
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
y_train = pd.DataFrame(y_train)
y_test = pd.DataFrame(y_test)

# %% [markdown]
# ### Export to csv

# %%
x_train.to_csv("../Data/x_train.csv", index = 0)
x_test.to_csv("../Data/x_test.csv", index = 0)
y_train.to_csv("../Data/y_train.csv", index = 0)
y_test.to_csv("../Data/y_test.csv", index = 0)
